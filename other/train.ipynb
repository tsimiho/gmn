# %%
import os
import os.path as osp
import sys
from math import ceil
import numpy as np

import torch
import torch.nn.functional as F
import torch_geometric
import torch_geometric.transforms as T
from dataset import GraphDataset
from models import *
from sklearn.metrics import normalized_mutual_info_score as NMI
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch_geometric import utils
from torch_geometric.loader import DataLoader
from torch_geometric.datasets import Planetoid, TUDataset
from torch_geometric.nn import DMoNPooling, GCNConv, GraphConv, Sequential
from torch_geometric.nn.conv.gcn_conv import gcn_norm
import torch.nn as nn

# %%
dataset = GraphDataset(torch.load("../data/cycle_line_star_complete_1_25+.pt"))

train_dataset, test_dataset = train_test_split(dataset, test_size=0.2, random_state=42)
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
def train(model, optimizer):
    model.train()
    total_loss = 0
    for data in train_loader:
        optimizer.zero_grad()
        output, loss = model(data)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)


@torch.no_grad()
def test(model, loader):
    model.eval()
    correct = 0
    total = 0
    for data in loader:
        output, _ = model(data)
        pred = torch.argmax(output, dim=1)
        target = data.node_classes
        batch = data.batch
        node_counter = [0] * len(target)
        for node_idx in range(data.num_nodes):
            graph_index = batch[node_idx].item()
            node_index = node_counter[graph_index]
            node_counter[graph_index] += 1
            true_classes = [c - 1 for c in target[graph_index][node_index]]
            predicted_class = pred[node_idx].item()

            if predicted_class in true_classes:
                correct += 1
        total += data.num_nodes
    accuracy = correct / total

    return accuracy


def run(model, optimizer, early_stopping):
    for epoch in range(1001):
        train_loss = train(model, optimizer)
        accuracy = test(model, test_loader)
        if epoch % 100 == 0:
            print(
                f"Epoch: {epoch:03d}, Loss: {train_loss:.4f}, Accuracy: {accuracy:.4f}"
            )
        early_stopping(train_loss)
        if early_stopping.early_stop:
            print("Early stopping")
            break

# %%
for m in [DMoN, JustBalance, MinCut]:
    for i in [5, 7, 10]:
        for j in [0, 1]:
            for dim in [32, 64]:
                for lr in [1e-2, 1e-3]:
                    model = m(
                        [64] * i,
                        "ReLU",
                        dataset.num_features,
                        len(np.unique(dataset[0].node_classes)),
                        [16] * j,
                        "ReLU",
                    )
                    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
                    early_stopping = EarlyStopping(patience=50)
                    print(f"{model.name}: {(i, j, dim, lr)}")
                    run(model, optimizer, early_stopping)
                    print("--------------------")
# Out:
# DMoN: (5, 0, 32, 0.01)
# Epoch: 000, Loss: 2.9924, Accuracy: 0.0409
# Early stopping
# --------------------
# DMoN: (5, 0, 32, 0.001)
# Epoch: 000, Loss: 3.2990, Accuracy: 0.0442
# Early stopping
# --------------------
# DMoN: (5, 0, 64, 0.01)
# Epoch: 000, Loss: 2.5027, Accuracy: 0.0433
# Early stopping
# --------------------
# DMoN: (5, 0, 64, 0.001)
# Epoch: 000, Loss: 3.6107, Accuracy: 0.0418
# Epoch: 100, Loss: 1.2649, Accuracy: 0.0409
# Early stopping
# --------------------
# DMoN: (5, 1, 32, 0.01)
# Epoch: 000, Loss: 2.4706, Accuracy: 0.0418
# Early stopping
# --------------------
# DMoN: (5, 1, 32, 0.001)
# Epoch: 000, Loss: 3.2851, Accuracy: 0.0452
# Epoch: 100, Loss: 1.2649, Accuracy: 0.0471
# Early stopping
# --------------------
# DMoN: (5, 1, 64, 0.01)
# Epoch: 000, Loss: 5.2033, Accuracy: 0.0428
# Early stopping
# --------------------
# DMoN: (5, 1, 64, 0.001)
# Epoch: 000, Loss: 3.4379, Accuracy: 0.0457
# Early stopping
# --------------------
# DMoN: (7, 0, 32, 0.01)
# Epoch: 000, Loss: 5.2577, Accuracy: 0.0495
# Early stopping
# --------------------
# DMoN: (7, 0, 32, 0.001)
# Epoch: 000, Loss: 4.7994, Accuracy: 0.0495
# Epoch: 100, Loss: 1.2566, Accuracy: 0.0452
# Epoch: 200, Loss: 1.2436, Accuracy: 0.0346
# Epoch: 300, Loss: 1.2285, Accuracy: 0.0447
# Epoch: 400, Loss: 1.1929, Accuracy: 0.0476
# Epoch: 500, Loss: 1.1903, Accuracy: 0.0428
# Epoch: 600, Loss: 1.1861, Accuracy: 0.0486
# Epoch: 700, Loss: 1.1801, Accuracy: 0.0495
# Epoch: 800, Loss: 1.1860, Accuracy: 0.0466
# Early stopping
# --------------------
# DMoN: (7, 0, 64, 0.01)
# Epoch: 000, Loss: 5.2572, Accuracy: 0.0481
# Early stopping
# --------------------
# DMoN: (7, 0, 64, 0.001)
# Epoch: 000, Loss: 4.5754, Accuracy: 0.0466
# Epoch: 100, Loss: 2.1855, Accuracy: 0.0452
# Epoch: 200, Loss: 1.2556, Accuracy: 0.0437
# Early stopping
# --------------------
# DMoN: (7, 1, 32, 0.01)
# Epoch: 000, Loss: 5.2529, Accuracy: 0.0447
# Early stopping
# --------------------
# DMoN: (7, 1, 32, 0.001)
# Epoch: 000, Loss: 4.2415, Accuracy: 0.0466
# Epoch: 100, Loss: 1.2215, Accuracy: 0.0442
# Epoch: 200, Loss: 1.1678, Accuracy: 0.0428
# Epoch: 300, Loss: 1.1476, Accuracy: 0.0495
# Epoch: 400, Loss: 1.1366, Accuracy: 0.0437
# Epoch: 500, Loss: 1.1223, Accuracy: 0.0447
# Epoch: 600, Loss: 1.1084, Accuracy: 0.0423
# Epoch: 700, Loss: 1.1186, Accuracy: 0.0370
# Epoch: 800, Loss: 1.1034, Accuracy: 0.0418
# Epoch: 900, Loss: 1.0886, Accuracy: 0.0389
# Epoch: 1000, Loss: 1.0853, Accuracy: 0.0418
# --------------------
# DMoN: (7, 1, 64, 0.01)
# Epoch: 000, Loss: 5.2605, Accuracy: 0.0418
# Early stopping
# --------------------
# DMoN: (7, 1, 64, 0.001)
# Epoch: 000, Loss: 4.6795, Accuracy: 0.0452
# Epoch: 100, Loss: 1.2649, Accuracy: 0.0409
# Early stopping
# --------------------
# DMoN: (10, 0, 32, 0.01)
# Epoch: 000, Loss: 5.2649, Accuracy: 0.0519
# Early stopping
# --------------------
# DMoN: (10, 0, 32, 0.001)
# Epoch: 000, Loss: 3.9566, Accuracy: 0.0433
# Epoch: 100, Loss: 1.2649, Accuracy: 0.0457
# Early stopping
# --------------------
# DMoN: (10, 0, 64, 0.01)
# Epoch: 000, Loss: 5.2649, Accuracy: 0.0428
# Early stopping
# --------------------
# DMoN: (10, 0, 64, 0.001)
# Epoch: 000, Loss: 5.0802, Accuracy: 0.0437
# Epoch: 100, Loss: 1.2649, Accuracy: 0.0481
# Early stopping
# --------------------
# DMoN: (10, 1, 32, 0.01)
# Epoch: 000, Loss: 5.2619, Accuracy: 0.0466
# Early stopping
# --------------------
# DMoN: (10, 1, 32, 0.001)
# Epoch: 000, Loss: 5.2064, Accuracy: 0.0447
# Early stopping
# --------------------
# DMoN: (10, 1, 64, 0.01)
# Epoch: 000, Loss: 5.2640, Accuracy: 0.0433
# Early stopping
# --------------------
# DMoN: (10, 1, 64, 0.001)
# Epoch: 000, Loss: 5.1947, Accuracy: 0.0495
# Early stopping
# --------------------
# JustBalance: (5, 0, 32, 0.01)
# Epoch: 000, Loss: -0.2154, Accuracy: 0.0495
# Early stopping
# --------------------
# JustBalance: (5, 0, 32, 0.001)
# Epoch: 000, Loss: -0.2135, Accuracy: 0.0457
# Epoch: 100, Loss: -0.2000, Accuracy: 0.0481
# Early stopping
# --------------------
# JustBalance: (5, 0, 64, 0.01)
# Epoch: 000, Loss: -0.2124, Accuracy: 0.0418
# Early stopping
# --------------------
# JustBalance: (5, 0, 64, 0.001)
# Epoch: 000, Loss: -0.2130, Accuracy: 0.0433
# Early stopping
# --------------------
# JustBalance: (5, 1, 32, 0.01)
# Epoch: 000, Loss: -0.2106, Accuracy: 0.0404
# Early stopping
# --------------------
# JustBalance: (5, 1, 32, 0.001)
# Epoch: 000, Loss: -0.2144, Accuracy: 0.0481
# Early stopping
# --------------------
# JustBalance: (5, 1, 64, 0.01)
# Epoch: 000, Loss: -0.2158, Accuracy: 0.0442
# Epoch: 100, Loss: -0.2910, Accuracy: 0.0404
# Epoch: 200, Loss: -0.2806, Accuracy: 0.0433
# Early stopping
# --------------------
# JustBalance: (5, 1, 64, 0.001)
# Epoch: 000, Loss: -0.2135, Accuracy: 0.0385
# Early stopping
# --------------------
# JustBalance: (7, 0, 32, 0.01)
# Epoch: 000, Loss: -0.2001, Accuracy: 0.0519
# Early stopping
# --------------------
# JustBalance: (7, 0, 32, 0.001)
# Epoch: 000, Loss: -0.2133, Accuracy: 0.0471
# Early stopping
# --------------------
# JustBalance: (7, 0, 64, 0.01)
# Epoch: 000, Loss: -0.2049, Accuracy: 0.0481
# Early stopping
# --------------------
# JustBalance: (7, 0, 64, 0.001)
# Epoch: 000, Loss: -0.2122, Accuracy: 0.0428
# Epoch: 100, Loss: -0.2552, Accuracy: 0.0433
# Early stopping
# --------------------
# JustBalance: (7, 1, 32, 0.01)
# Epoch: 000, Loss: -0.2075, Accuracy: 0.0447
# Early stopping
# --------------------
# JustBalance: (7, 1, 32, 0.001)
# Epoch: 000, Loss: -0.2138, Accuracy: 0.0452
# Early stopping
# --------------------
# JustBalance: (7, 1, 64, 0.01)
# Epoch: 000, Loss: -0.2042, Accuracy: 0.0433
# Early stopping
# --------------------
# JustBalance: (7, 1, 64, 0.001)
# Epoch: 000, Loss: -0.2136, Accuracy: 0.0519
# Early stopping
# --------------------
# JustBalance: (10, 0, 32, 0.01)
# Epoch: 000, Loss: -0.2001, Accuracy: 0.0466
# Early stopping
# --------------------
# JustBalance: (10, 0, 32, 0.001)
# Epoch: 000, Loss: -0.2074, Accuracy: 0.0413
# Early stopping
# --------------------
# JustBalance: (10, 0, 64, 0.01)
# Epoch: 000, Loss: -0.2001, Accuracy: 0.0442
# Early stopping
# --------------------
# JustBalance: (10, 0, 64, 0.001)
# Epoch: 000, Loss: -0.2048, Accuracy: 0.0457
# Early stopping
# --------------------
# JustBalance: (10, 1, 32, 0.01)
# Epoch: 000, Loss: -0.2000, Accuracy: 0.0442
# Early stopping
# --------------------
# JustBalance: (10, 1, 32, 0.001)
# Epoch: 000, Loss: -0.2105, Accuracy: 0.0418
# Epoch: 100, Loss: -0.2996, Accuracy: 0.0457
# Early stopping
# --------------------
# JustBalance: (10, 1, 64, 0.01)
# Epoch: 000, Loss: -0.2001, Accuracy: 0.0428
# Early stopping
# --------------------
# JustBalance: (10, 1, 64, 0.001)
# Epoch: 000, Loss: -0.2116, Accuracy: 0.0466
# Early stopping
# --------------------
# MinCut: (5, 0, 32, 0.01)
# Epoch: 000, Loss: 0.2651, Accuracy: 0.0495
# Early stopping
# --------------------
# MinCut: (5, 0, 32, 0.001)
# Epoch: 000, Loss: 0.2675, Accuracy: 0.0519
# Epoch: 100, Loss: 0.2649, Accuracy: 0.0519
# Early stopping
# --------------------
# MinCut: (5, 0, 64, 0.01)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0433
# Early stopping
# --------------------
# MinCut: (5, 0, 64, 0.001)
# Epoch: 000, Loss: 0.2652, Accuracy: 0.0442
# Early stopping
# --------------------
# MinCut: (5, 1, 32, 0.01)
# Epoch: 000, Loss: 0.2650, Accuracy: 0.0495
# Early stopping
# --------------------
# MinCut: (5, 1, 32, 0.001)
# Epoch: 000, Loss: 0.2665, Accuracy: 0.0457
# Early stopping
# --------------------
# MinCut: (5, 1, 64, 0.01)
# Epoch: 000, Loss: 0.2650, Accuracy: 0.0447
# Early stopping
# --------------------
# MinCut: (5, 1, 64, 0.001)
# Epoch: 000, Loss: 0.2656, Accuracy: 0.0433
# Epoch: 100, Loss: 0.2649, Accuracy: 0.0433
# Early stopping
# --------------------
# MinCut: (7, 0, 32, 0.01)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0466
# Early stopping
# --------------------
# MinCut: (7, 0, 32, 0.001)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0452
# Early stopping
# --------------------
# MinCut: (7, 0, 64, 0.01)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0428
# Early stopping
# --------------------
# MinCut: (7, 0, 64, 0.001)
# Epoch: 000, Loss: 0.2650, Accuracy: 0.0457
# Early stopping
# --------------------
# MinCut: (7, 1, 32, 0.01)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0495
# Early stopping
# --------------------
# MinCut: (7, 1, 32, 0.001)
# Epoch: 000, Loss: 0.2651, Accuracy: 0.0433
# Epoch: 100, Loss: 0.2649, Accuracy: 0.0433
# Early stopping
# --------------------
# MinCut: (7, 1, 64, 0.01)
# Epoch: 000, Loss: 0.2652, Accuracy: 0.0466
# Early stopping
# --------------------
# MinCut: (7, 1, 64, 0.001)
# Epoch: 000, Loss: 0.2681, Accuracy: 0.0442
# Epoch: 100, Loss: 0.2649, Accuracy: 0.0442
# Early stopping
# --------------------
# MinCut: (10, 0, 32, 0.01)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0447
# Early stopping
# --------------------
# MinCut: (10, 0, 32, 0.001)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0471
# Early stopping
# --------------------
# MinCut: (10, 0, 64, 0.01)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0495
# Early stopping
# --------------------
# MinCut: (10, 0, 64, 0.001)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0428
# Early stopping
# --------------------
# MinCut: (10, 1, 32, 0.01)
# Epoch: 000, Loss: 0.2649, Accuracy: 0.0433
# Early stopping
# --------------------
# MinCut: (10, 1, 32, 0.001)
# Epoch: 000, Loss: 0.2651, Accuracy: 0.0433
# Early stopping
# --------------------
# MinCut: (10, 1, 64, 0.01)
# Epoch: 000, Loss: 0.2650, Accuracy: 0.0457
# Early stopping
# --------------------
# MinCut: (10, 1, 64, 0.001)
# Epoch: 000, Loss: 0.2650, Accuracy: 0.0452
# Early stopping
# --------------------

# %%
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(loader.dataset)


def test(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out = model(data)
            pred = out.argmax(dim=1)
            correct += int((pred == data.y).sum())
            total += data.num_graphs
    return correct / total
