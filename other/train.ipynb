# %%
import os
import os.path as osp
import sys
from math import ceil
import numpy as np

import torch
import torch.nn.functional as F
import torch_geometric
import torch_geometric.transforms as T
from dataset import GraphDataset
from models import *
from sklearn.metrics import normalized_mutual_info_score as NMI
from sklearn.model_selection import train_test_split
from torch.nn import Linear
from torch_geometric import utils
from torch_geometric.loader import DataLoader
from torch_geometric.datasets import Planetoid, TUDataset
from torch_geometric.nn import DMoNPooling, GCNConv, GraphConv, Sequential
from torch_geometric.nn.conv.gcn_conv import gcn_norm
import torch.nn as nn

# %%
dataset = GraphDataset(torch.load("../data/cycle_line_star_complete_1_15.pt"))

train_dataset, test_dataset = train_test_split(dataset, test_size=0.2, random_state=42)
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
def train(model, optimizer):
    model.train()
    total_loss = 0
    for data in train_loader:
        optimizer.zero_grad()
        output, loss = model(data)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)


@torch.no_grad()
def test(model, loader):
    model.eval()
    correct = 0
    total = 0
    for data in loader:
        output, _ = model(data)
        pred = torch.argmax(output, dim=1)
        target = data.node_classes
        batch = data.batch
        node_counter = [0] * len(target)
        for node_idx in range(data.num_nodes):
            graph_index = batch[node_idx].item()
            node_index = node_counter[graph_index]
            node_counter[graph_index] += 1
            true_classes = [c - 1 for c in target[graph_index][node_index]]
            predicted_class = pred[node_idx].item()

            if predicted_class in true_classes:
                correct += 1
        total += data.num_nodes
    accuracy = correct / total

    return accuracy


def run(model, optimizer, early_stopping):
    for epoch in range(1001):
        train_loss = train(model, optimizer)
        accuracy = test(model, test_loader)
        if epoch % 100 == 0:
            print(
                f"Epoch: {epoch:03d}, Loss: {train_loss:.4f}, Accuracy: {accuracy:.4f}"
            )
        early_stopping(train_loss)
        if early_stopping.early_stop:
            print("Early stopping")
            break

# %%
for m in [DMoN, JustBalance, MinCut]:
    for i in [5, 7, 10]:
        for j in [0, 1]:
            for dim in [32, 64]:
                for lr in [1e-3, 1e-4]:
                    model = m(
                        [64] * i,
                        "ReLU",
                        dataset.num_features,
                        len(np.unique(dataset[0].node_classes)),
                        [16] * j,
                        "ReLU",
                    )
                    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
                    early_stopping = EarlyStopping(patience=50)
                    print(f"{model.name}: {(i, j, dim, lr)}")
                    run(model, optimizer, early_stopping)
                    print("--------------------")
# Out:
# DMoN: (5, 0, 32, 0.001)
# Epoch: 000, Loss: 2.6618, Accuracy: 0.0839
# Early stopping
# --------------------
# DMoN: (5, 0, 32, 0.0001)
# Epoch: 000, Loss: 2.6919, Accuracy: 0.0839
# Epoch: 100, Loss: 1.9765, Accuracy: 0.0753
# Early stopping
# --------------------
# DMoN: (5, 0, 64, 0.001)
# Epoch: 000, Loss: 2.3687, Accuracy: 0.0745
# Early stopping
# --------------------
# DMoN: (5, 0, 64, 0.0001)
# Epoch: 000, Loss: 2.6132, Accuracy: 0.0769
# Epoch: 100, Loss: 2.7561, Accuracy: 0.0784
# Early stopping
# --------------------
# DMoN: (5, 1, 32, 0.001)
# Epoch: 000, Loss: 2.5694, Accuracy: 0.0839
# Epoch: 100, Loss: 1.2180, Accuracy: 0.0761
# Early stopping
# --------------------
# DMoN: (5, 1, 32, 0.0001)
# Epoch: 000, Loss: 2.8102, Accuracy: 0.0738
# Early stopping
# --------------------
# DMoN: (5, 1, 64, 0.001)
# Epoch: 000, Loss: 2.5431, Accuracy: 0.0738
# Epoch: 100, Loss: 1.2180, Accuracy: 0.0761
# Early stopping
# --------------------
# DMoN: (5, 1, 64, 0.0001)
# Epoch: 000, Loss: 2.2288, Accuracy: 0.0738
# Early stopping
# --------------------
# DMoN: (7, 0, 32, 0.001)
# Epoch: 000, Loss: 3.8189, Accuracy: 0.0691
# Epoch: 100, Loss: 1.0713, Accuracy: 0.0823
# Epoch: 200, Loss: 1.0379, Accuracy: 0.0784
# Epoch: 300, Loss: 1.0250, Accuracy: 0.0784
# Epoch: 400, Loss: 1.0122, Accuracy: 0.0683
# Epoch: 500, Loss: 1.0045, Accuracy: 0.0800
# Epoch: 600, Loss: 0.9953, Accuracy: 0.0707
# Epoch: 700, Loss: 0.9877, Accuracy: 0.0738
# Early stopping
# --------------------
# DMoN: (7, 0, 32, 0.0001)
# Epoch: 000, Loss: 3.1611, Accuracy: 0.0916
# Epoch: 100, Loss: 1.9578, Accuracy: 0.0660
# Early stopping
# --------------------
# DMoN: (7, 0, 64, 0.001)
# Epoch: 000, Loss: 3.1943, Accuracy: 0.0691
# Epoch: 100, Loss: 1.7774, Accuracy: 0.0970
# Epoch: 200, Loss: 1.7166, Accuracy: 0.0784
# Epoch: 300, Loss: 1.6983, Accuracy: 0.0776
# Early stopping
# --------------------
# DMoN: (7, 0, 64, 0.0001)
# Epoch: 000, Loss: 3.4320, Accuracy: 0.0738
# Epoch: 100, Loss: 2.1681, Accuracy: 0.0776
# Early stopping
# --------------------
# DMoN: (7, 1, 32, 0.001)
# Epoch: 000, Loss: 3.3930, Accuracy: 0.0738
# Epoch: 100, Loss: 1.2180, Accuracy: 0.0761
# Early stopping
# --------------------
# DMoN: (7, 1, 32, 0.0001)
# Epoch: 000, Loss: 3.0451, Accuracy: 0.0893
# Epoch: 100, Loss: 2.2989, Accuracy: 0.0707
# Early stopping
# --------------------
# DMoN: (7, 1, 64, 0.001)
# Epoch: 000, Loss: 3.7356, Accuracy: 0.0761
# Early stopping
# --------------------
# DMoN: (7, 1, 64, 0.0001)
# Epoch: 000, Loss: 3.7165, Accuracy: 0.0722
# Epoch: 100, Loss: 2.2884, Accuracy: 0.0714
# Early stopping
# --------------------
# DMoN: (10, 0, 32, 0.001)
# Epoch: 000, Loss: 4.0852, Accuracy: 0.0916
# Early stopping
# --------------------
# DMoN: (10, 0, 32, 0.0001)
# Epoch: 000, Loss: 3.7194, Accuracy: 0.0722
# Epoch: 100, Loss: 2.6688, Accuracy: 0.0675
# Epoch: 200, Loss: 1.2180, Accuracy: 0.0769
# Epoch: 300, Loss: 1.2180, Accuracy: 0.0753
# Early stopping
# --------------------
# DMoN: (10, 0, 64, 0.001)
# Epoch: 000, Loss: 3.8556, Accuracy: 0.0753
# Epoch: 100, Loss: 1.7930, Accuracy: 0.0761
# Early stopping
# --------------------
# DMoN: (10, 0, 64, 0.0001)
# Epoch: 000, Loss: 3.8982, Accuracy: 0.0916
# Epoch: 100, Loss: 2.7938, Accuracy: 0.0738
# Epoch: 200, Loss: 2.7701, Accuracy: 0.0784
# Epoch: 300, Loss: 1.8934, Accuracy: 0.0885
# Epoch: 400, Loss: 1.4742, Accuracy: 0.0792
# Epoch: 500, Loss: 1.1863, Accuracy: 0.0769
# Epoch: 600, Loss: 1.2184, Accuracy: 0.0730
# Epoch: 700, Loss: 1.1407, Accuracy: 0.0823
# Epoch: 800, Loss: 1.4124, Accuracy: 0.0714
# Early stopping
# --------------------
# DMoN: (10, 1, 32, 0.001)
# Epoch: 000, Loss: 3.9837, Accuracy: 0.0722
# Epoch: 100, Loss: 1.2180, Accuracy: 0.0769
# Early stopping
# --------------------
# DMoN: (10, 1, 32, 0.0001)
# Epoch: 000, Loss: 3.5610, Accuracy: 0.0691
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 17
#      15 early_stopping = EarlyStopping(patience=50)
#      16 print(f"{model.name}: {(i, j, dim, lr)}")
# ---> 17 run(model, optimizer, early_stopping)
#      18 print("--------------------")
#
# Cell In[4], line 41, in run(model, optimizer, early_stopping)
#      39 def run(model, optimizer, early_stopping):
#      40     for epoch in range(1001):
# ---> 41         train_loss = train(model, optimizer)
#      42         accuracy = test(model, test_loader)
#      43         if epoch % 100 == 0:
#
# Cell In[4], line 6, in train(model, optimizer)
#       4 for data in train_loader:
#       5     optimizer.zero_grad()
# ----> 6     output, loss = model(data)
#       7     loss.backward()
#       8     optimizer.step()
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Desktop/NTUA/ECE/DiplomaThesis/Code/repo/gmn/other/models.py:76, in DMoN.forward(self, data)
#      74 def forward(self, data):
#      75     x, edge_index = data.x, data.edge_index
# ---> 76     x = self.mp(x, edge_index)
#      77     s = self.mlp(x)
#      78     adj = utils.to_dense_adj(edge_index)
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /var/folders/st/cyh3v8ln22sdswp1s386w5vw0000gn/T/torch_geometric.nn.sequential_fe8f70__f_lis67.py:65, in Sequential.forward(self, x, edge_index)
#      63 x = self.module_8(x, edge_index)
#      64 x = self.module_9(x)
# ---> 65 x = self.module_10(x, edge_index)
#      66 x = self.module_11(x)
#      67 x = self.module_12(x, edge_index)
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/homebrew/lib/python3.10/site-packages/torch_geometric/nn/conv/gcn_conv.py:263, in GCNConv.forward(self, x, edge_index, edge_weight)
#     260 x = self.lin(x)
#     262 # propagate_type: (x: Tensor, edge_weight: OptTensor)
# --> 263 out = self.propagate(edge_index, x=x, edge_weight=edge_weight)
#     265 if self.bias is not None:
#     266     out = out + self.bias
#
# File /opt/homebrew/lib/python3.10/site-packages/torch_geometric/nn/conv/message_passing.py:565, in MessagePassing.propagate(self, edge_index, size, **kwargs)
#     562     if res is not None:
#     563         aggr_kwargs = res[0] if isinstance(res, tuple) else res
# --> 565 out = self.aggregate(out, **aggr_kwargs)
#     567 for hook in self._aggregate_forward_hooks.values():
#     568     res = hook(self, (aggr_kwargs, ), out)
#
# File /opt/homebrew/lib/python3.10/site-packages/torch_geometric/nn/conv/message_passing.py:618, in MessagePassing.aggregate(self, inputs, index, ptr, dim_size)
#     601 def aggregate(
#     602     self,
#     603     inputs: Tensor,
#    (...)
#     606     dim_size: Optional[int] = None,
#     607 ) -> Tensor:
#     608     r"""Aggregates messages from neighbors as
#     609     :math:`\bigoplus_{j \in \mathcal{N}(i)}`.
#     610
#    (...)
#     616     as specified in :meth:`__init__` by the :obj:`aggr` argument.
#     617     """
# --> 618     return self.aggr_module(inputs, index, ptr=ptr, dim_size=dim_size,
#     619                             dim=self.node_dim)
#
# File /opt/homebrew/lib/python3.10/site-packages/torch_geometric/experimental.py:117, in disable_dynamic_shapes.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     114 @functools.wraps(func)
#     115 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     116     if not is_experimental_mode_enabled('disable_dynamic_shapes'):
# --> 117         return func(*args, **kwargs)
#     119     for required_arg in required_args:
#     120         index = required_args_pos[required_arg]
#
# File /opt/homebrew/lib/python3.10/site-packages/torch_geometric/nn/aggr/base.py:128, in Aggregation.__call__(self, x, index, ptr, dim_size, dim, **kwargs)
#     125     dim_size = int(index.max()) + 1 if index.numel() > 0 else 0
#     127 try:
# --> 128     return super().__call__(x, index=index, ptr=ptr, dim_size=dim_size,
#     129                             dim=dim, **kwargs)
#     130 except (IndexError, RuntimeError) as e:
#     131     if index is not None:
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/homebrew/lib/python3.10/site-packages/torch_geometric/nn/aggr/basic.py:19, in SumAggregation.forward(self, x, index, ptr, dim_size, dim)
#      12 class SumAggregation(Aggregation):
#      13     r"""An aggregation operator that sums up features across a set of elements.
#      14
#      15     .. math::
#      16         \mathrm{sum}(\mathcal{X}) = \sum_{\mathbf{x}_i \in \mathcal{X}}
#      17         \mathbf{x}_i.
#      18     """
# ---> 19     def forward(self, x: Tensor, index: Optional[Tensor] = None,
#      20                 ptr: Optional[Tensor] = None, dim_size: Optional[int] = None,
#      21                 dim: int = -2) -> Tensor:
#      22         return self.reduce(x, index, ptr, dim_size, dim, reduce='sum')
#
# KeyboardInterrupt:

# %%
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(loader.dataset)


def test(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out = model(data)
            pred = out.argmax(dim=1)
            correct += int((pred == data.y).sum())
            total += data.num_graphs
    return correct / total
